# %% [markdown]
# ## Quinn's Quick Quality Checker

# %%
#import
import pandas as pd
import polars as pl

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set data

# %%
#read data
df = pl.read_csv('/Users/QuinnScot/Desktop/AI/P5/DM/course_dmt/ass2/datasets/training_set_VU_DM.csv')

# %%
#sample randomly 10% of the data into a new dataframe
fraction = 0.2

df_sample = df.sample(frac=fraction, seed=1)

#save polars df to csv
df_sample.write_csv(f'/Users/QuinnScot/Desktop/AI/P5/DM/course_dmt/ass2/datasets/sample_{fraction}_training_set.csv')

# %%
df.head()
# Out:
# shape: (5, 54)
# ┌─────────┬─────────┬─────────┬────────────┬─────┬────────────┬──────────┬────────────┬────────────┐
# │ srch_id ┆ date_ti ┆ site_id ┆ visitor_lo ┆ ... ┆ comp8_rate ┆ click_bo ┆ gross_book ┆ booking_bo │
# │ ---     ┆ me      ┆ ---     ┆ cation_cou ┆     ┆ _percent_d ┆ ol       ┆ ings_usd   ┆ ol         │
# │ i64     ┆ ---     ┆ i64     ┆ ntry_id    ┆     ┆ iff        ┆ ---      ┆ ---        ┆ ---        │
# │         ┆ str     ┆         ┆ ---        ┆     ┆ ---        ┆ i64      ┆ str        ┆ i64        │
# │         ┆         ┆         ┆ i64        ┆     ┆ str        ┆          ┆            ┆            │
# ╞═════════╪═════════╪═════════╪════════════╪═════╪════════════╪══════════╪════════════╪════════════╡
# │ 1       ┆ 2013-04 ┆ 12      ┆ 187        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -04 08: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │         ┆ 32:15   ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 1       ┆ 2013-04 ┆ 12      ┆ 187        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -04 08: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │         ┆ 32:15   ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 1       ┆ 2013-04 ┆ 12      ┆ 187        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -04 08: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │         ┆ 32:15   ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 1       ┆ 2013-04 ┆ 12      ┆ 187        ┆ ... ┆ 5          ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -04 08: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │         ┆ 32:15   ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 1       ┆ 2013-04 ┆ 12      ┆ 187        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -04 08: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# │         ┆ 32:15   ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# └─────────┴─────────┴─────────┴────────────┴─────┴────────────┴──────────┴────────────┴────────────┘
