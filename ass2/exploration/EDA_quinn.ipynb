# %% [markdown]
# ## Quinn's Quick Quality Checker

# %%
#import
import pandas as pd
import polars as pl

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Set data

# %%
#read data
input_data = pl.read_csv('/Users/QuinnScot/Desktop/AI/P5/DM/course_dmt/ass2/datasets/training_set_VU_DM.csv')

# %%
#sample randomly 10% of the data into a new dataframe
fraction = 0.01

df_sample = input_data.sample(frac=fraction, seed=1)

#save polars df to csv
# df_sample.write_csv(f'/Users/QuinnScot/Desktop/AI/P5/DM/course_dmt/ass2/datasets/sample_{fraction}_training_set.csv')

df = df_sample

# %%
df.head()
# print(df.select("date_time")[0])
# Out:
# shape: (5, 54)
# ┌─────────┬─────────┬─────────┬────────────┬─────┬────────────┬──────────┬────────────┬────────────┐
# │ srch_id ┆ date_ti ┆ site_id ┆ visitor_lo ┆ ... ┆ comp8_rate ┆ click_bo ┆ gross_book ┆ booking_bo │
# │ ---     ┆ me      ┆ ---     ┆ cation_cou ┆     ┆ _percent_d ┆ ol       ┆ ings_usd   ┆ ol         │
# │ i64     ┆ ---     ┆ i64     ┆ ntry_id    ┆     ┆ iff        ┆ ---      ┆ ---        ┆ ---        │
# │         ┆ str     ┆         ┆ ---        ┆     ┆ ---        ┆ i64      ┆ str        ┆ i64        │
# │         ┆         ┆         ┆ i64        ┆     ┆ str        ┆          ┆            ┆            │
# ╞═════════╪═════════╪═════════╪════════════╪═════╪════════════╪══════════╪════════════╪════════════╡
# │ 99808   ┆ 2013-04 ┆ 5       ┆ 219        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -28 10: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# ...

# %%
df = df.with_columns(
        pl.col('date_time')
        .str.strptime(pl.Datetime,
                      strict=False)
        .alias('date_time')
    )
df.head()
# Out:
# shape: (5, 54)
# ┌─────────┬─────────┬─────────┬────────────┬─────┬────────────┬──────────┬────────────┬────────────┐
# │ srch_id ┆ date_ti ┆ site_id ┆ visitor_lo ┆ ... ┆ comp8_rate ┆ click_bo ┆ gross_book ┆ booking_bo │
# │ ---     ┆ me      ┆ ---     ┆ cation_cou ┆     ┆ _percent_d ┆ ol       ┆ ings_usd   ┆ ol         │
# │ i64     ┆ ---     ┆ i64     ┆ ntry_id    ┆     ┆ iff        ┆ ---      ┆ ---        ┆ ---        │
# │         ┆ datetim ┆         ┆ ---        ┆     ┆ ---        ┆ i64      ┆ str        ┆ i64        │
# │         ┆ e[μs]   ┆         ┆ i64        ┆     ┆ str        ┆          ┆            ┆            │
# ╞═════════╪═════════╪═════════╪════════════╪═════╪════════════╪══════════╪════════════╪════════════╡
# │ 99808   ┆ 2013-04 ┆ 5       ┆ 219        ┆ ... ┆ NULL       ┆ 0        ┆ NULL       ┆ 0          │
# │         ┆ -28 10: ┆         ┆            ┆     ┆            ┆          ┆            ┆            │
# ...

# %%
#find range of date_time
print(df.select(pl.min('date_time')), df.select(pl.max('date_time')))
# Out:
# shape: (1, 1)
# ┌─────────────────────┐
# │ date_time           │
# │ ---                 │
# │ datetime[μs]        │
# ╞═════════════════════╡
# │ 2012-11-01 00:43:40 │
# └─────────────────────┘ shape: (1, 1)
# ┌─────────────────────┐
# │ date_time           │
# │ ---                 │
# │ datetime[μs]        │
# ╞═════════════════════╡
# │ 2013-06-30 23:45:53 │
# └─────────────────────┘
