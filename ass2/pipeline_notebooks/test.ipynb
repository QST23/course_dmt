# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import random, os, sys, time

# %%
#read data
df = pd.read_csv('../datasets/feature_0.1_sample.csv')

train_df = df.sample(frac=0.8, random_state=0)

# %%
train_df
# Out:
#         srch_id  site_id  visitor_location_country_id  prop_country_id
# 299036   321676        5                          219              219  \
# 91770    156577       24                          216               92
# 482444   159973        1                           13              215
# 239662    92390       31                          219              219
# 485393    66300       15                           55               55
# ...         ...      ...                          ...              ...
# 487453    25037       16                           31               31
# 409211     7198        5                          219              219
# 200392   251312        5                          219              219
# 411106   115953        5                           41              205
# 71388    260715       25                          215              215
#
#         prop_id  prop_starrating  prop_review_score  prop_brand_bool
# ...

# %%
groups = train_df.groupby('srch_id').size().to_frame('size')['size'].to_numpy()
groups
# Out:
# array([3, 5, 2, ..., 4, 1, 1])

# %%
print(len(groups))
# Out:
# 164410
